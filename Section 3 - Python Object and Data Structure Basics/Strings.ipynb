# %%
'hello'
# Out:
# 'hello'

# %%
"hello world"
# Out:
# 'hello world'

# %%
'this is ALSO A STRING'
# Out:
# 'this is ALSO A STRING'

# %%
"Im gonna run"
# Out:
# 'Im gonna run'

# %%
print("hello")
# Out:
# hello

# %%
print("hello world one")
'hello world two'
# Out:
# hello world one
# 'hello world two'

# %%
print('hello \tworld')
# Out:
# hello 	world

# %%
len('hello world')
# Out:
# 11

# %%
mystring="hello world"

# %%
mystring
# Out:
# 'hello world'

# %%
mystring[0]
# Out:
# 'h'

# %%
mystring[8]
# Out:
# 'r'

# %%
mystring='abcdefghijk'

# %%
mystring
# Out:
# 'abcdefghijk'

# %%
mystring[2:]
# Out:
# 'cdefghijk'

# %%
mystring[:3]
# Out:
# 'abc'

# %%
mystring[3:9]
# Out:
# 'defghi'

# %%
mystring[::3]
# Out:
# 'adgj'

# %%
mystring[::-2]
# Out:
# 'kigeca'

# %%
name='Sam'
