# %% [markdown]
# # Formatting with the .format() method
# A good way to format objects into your strings for print statements is with the string .format() method.
#
# The syntax is:
#
# 'String here {} then also {}'.format('something1','something2')

# %%
print('This is a string {}'.format('INSERTED'))
# Out:
# This is a string INSERTED

# %%
print('The {0} {0} {0}'.format('fox','brown','quick'))
# Out:
# The fox fox fox

# %%
print('The {q} {b} {f}'.format(f='fox', b='brown', q='quick'))
# Out:
# The quick brown fox

# %% [markdown]
# # Float formatting follows

# %%
result = 100/777

# %%
result = 104.12345

# %%
print("The result was {r:1.5f}".format(r=result))
# Out:
# The result was 104.12345

# %%
name = "Jose"

# %%
print(f"Hello, his name is {name}")
# Out:
# Hello, his name is Jose

# %%
name = "Srihas"
age=  3

# %%
print(f"{name} is {age} years old. Aww he's such a baaabyyy")
# Out:
# Srihas is 3 years old. Aww he's such a baaabyyy
