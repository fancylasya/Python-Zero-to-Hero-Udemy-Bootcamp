# %% [markdown]
# ### Formatting with the .format() method
# A good way to format objects into your strings for print statements is with the string .format() method. The syntax is:
#
# **'String here {} then also {}'.format('something1','something2')**

# %%
print('This is a string {}'.format('INSERTED'))
# Out:
# This is a string INSERTED

# %%
print("The {2} {1} {0}".format('fox', 'brown', 'quick'))
# Out:
# The quick brown fox

# %%
print("The {q} {b} {f}".format(f="fox", b="brown", q="quick"))
# Out:
# The quick brown fox

# %% [markdown]
# **Float formatting follows "{value:width.precision *f*}"**

# %%
result = 100/777

# %%
result
# Out:
# 0.1287001287001287

# %%
print("The result was {r:1.7f}".format(r = result))
# Out:
# The result was 104.1234500

# %%
result = 104.12345

# %%
name = "Srihas"

# %%
print("Hello, his name is {}".format(name))
# Out:
# Hello, his name is Srihas

# %%
print(f"Hello, his name is {name}")
# Out:
# Hello, his name is Srihas

# %%
age = 19

# %%
print(f"{name} is {age} years old.")
# Out:
# Srihas is 19 years old.

# %%
print(name, "is", age, "years old.")
# Out:
# Srihas is 19 years old.

# %%
print(name + " is " + str(age) + " years old.")
# Out:
# Srihas is 19 years old.
