# %% [markdown]
# ## Immutability

# %%
name = "Sam"

# %%
# name[0] = 'P'

# %%
last_letters = name[1:]

# %%
last_letters
# Out:
# 'am'

# %%
'P' + last_letters
# Out:
# 'Pam'

# %%
x = "Hello World! "

# %%
x = x + "it is beautiful outside"

# %%
x
# Out:
# 'Hello World! it is beautiful outsideit is beautiful outsideit is beautiful outsideit is beautiful outsideit is beautiful outsideit is beautiful outside'

# %%
letter = 'z'

# %%
letter * 10
# Out:
# 'zzzzzzzzzz'

# %%
2 + 3
# Out:
# 5

# %%
'2' + '3'
# Out:
# '23'

# %%
x = 'hello world!'

# %%
x.upper()
# Out:
# 'HELLO WORLD!'

# %%
x = x.upper()

# %%
x
# Out:
# 'HELLO WORLD!'

# %%
x = x.lower()

# %%
x
# Out:
# 'hello world!'

# %%
x.split()
# Out:
# ['hello', 'world!']

# %%
x = "Hi this is a string!"

# %%
x.split()
# Out:
# ['Hi', 'this', 'is', 'a', 'string!']

# %%
x.split('i')
# Out:
# ['H', ' th', 's ', 's a str', 'ng!']
