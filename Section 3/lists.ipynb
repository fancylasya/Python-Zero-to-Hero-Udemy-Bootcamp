# %%
my_list = [1,2,3]

# %%
my_list
# Out:
# [1, 2, 3]

# %%
my_list = ["string", 1000, 99.4]

# %%
len(my_list)
# Out:
# 3

# %% [markdown]
# lists operate very similar to a string. slicing and indexing works the same

# %%
my_list[1:]
# Out:
# [1000, 99.4]

# %%
other_list = [1,2,3,4,5]

# %%
combined_list = my_list + other_list

# %%
print(combined_list)
# Out:
# ['string', 1000, 99.4, 1, 2, 3, 4, 5]

# %%
my_list = ["one", "two", "three"]

# %%
other_list = ["four", "five"]

# %%
combined_list = my_list + other_list

# %%
combined_list
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
combined_list[0] = "ONE ALL CAPS"

# %%
combined_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five']

# %%
combined_list.append("six")

# %%
print(combined_list)
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five', 'six']

# %%
combined_list.append("seven")

# %%
print(combined_list)
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five', 'six', 'seven']

# %%
combined_list.pop()
# Out:
# 'seven'

# %%
combined_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five', 'six']

# %%
popped_item = combined_list.pop()

# %%
popped_item
# Out:
# 'six'

# %%
print(combined_list)
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five']

# %%
combined_list.pop(0)
# Out:
# 'ONE ALL CAPS'

# %%
combined_list
# Out:
# ['two', 'three', 'four', 'five']

# %%
combined_list.pop(-1) # reverse indexing also works!
# Out:
# 'five'

# %%
combined_list
# Out:
# ['two', 'three', 'four']

# %% [markdown]
# common list methods include sort and reverse

# %%
new_list = ['q','w','e','r','t','y']

# %%
num_list = [113,26,919,5555]

# %%
new_list.sort()

# %%
new_list
# Out:
# ['e', 'q', 'r', 't', 'w', 'y']

# %%
new_list = ['q','w','e','r','t','y']

# %%
print(sorted(new_list))
# Out:
# ['e', 'q', 'r', 't', 'w', 'y']

# %%
num_list
# Out:
# [113, 26, 919, 5555]

# %%
num_list.reverse()

# %%
num_list
# Out:
# [5555, 919, 26, 113]

# %%
nested_list = [1, 2, [3.1, 3.2]]

# %%
print(nested_list)
# Out:
# [1, 2, [3.1, 3.2]]

# %%
print(nested_list[2])
# Out:
# [3.1, 3.2]

# %%
print(nested_list[2][0])
# Out:
# 3.1
