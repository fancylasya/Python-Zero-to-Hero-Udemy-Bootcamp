# %%
'hello'
# Out:
# 'hello'

# %%
"world"
# Out:
# 'world'

# %%
'this is also a string'
# Out:
# 'this is also a string'

# %%
" I'm going on a run! "
# Out:
# " I'm going on a run! "

# %%
print("hello world!")
# Out:
# hello world!

# %%
print("hello \nworld")
# Out:
# hello
# world

# %%
mystring = "Hello World"

# %%
mystring
# Out:
# 'Hello World'

# %%
mystring[0]
# Out:
# 'H'

# %%
mystring[1]
# Out:
# 'e'

# %%
mystring[8]
# Out:
# 'r'

# %%
mystring[-1]
# Out:
# 'd'

# %%
mystring[9]
# Out:
# 'l'

# %%
mystring[-2]
# Out:
# 'l'

# %%
mystring
# Out:
# 'Hello World'

# %%
mystring = 'abcdefghijk'

# %%
mystring
# Out:
# 'abcdefghijk'

# %%
mystring[2]
# Out:
# 'c'

# %%
mystring[2:]
# Out:
# 'cdefghijk'

# %%
mystring[:3]
# Out:
# 'abc'

# %%
mystring[3:6]
# Out:
# 'def'

# %%
mystring[1:3]
# Out:
# 'bc'

# %%
mystring[3:9]
# Out:
# 'defghi'

# %%
mystring[::]
# Out:
# 'abcdefghijk'

# %%
mystring[::3]
# Out:
# 'adgj'

# %%
mystring[::-1]
# Out:
# 'kjihgfedcba'

# %%
mystring[::-2]
# Out:
# 'kigeca'
